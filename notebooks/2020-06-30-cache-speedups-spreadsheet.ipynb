# %%
import sys
sys.path.append("../analysis")

# %%
import parsing
import extraction
import utils

# %%
from extraction import pull_spec_in, select_categories
from utils import fetch, split_spec_pretty

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
STATE_CACHE_FILES = {
    "Viable": '2020-06-29-cache-all-viable-with-ultimate-result',
    "Falsely viable": '2020-06-29-cache-false-on-viable-but-mistaken',
    "Truly viable": '2020-06-29-cache-on-viable-and-in-solution',
    "Nonviable": '2020-06-29-cache-only-when-nonviable',
    "All": '2020-06-29-cache-all-pruning-results'
}

# %%
data = {t: pull_spec_in(select_categories(fetch(f), ["search"]))
       for t, f in STATE_CACHE_FILES.items()}

# %%
data['Viable'].columns
# Out:
# Index(['category', 'key', 'success', 'mode', 'cache_reuse', 'prune_fuel',
#        'time', 'spec'],
#       dtype='object')

# %%
frames = []
for test, raw_frame in data.items():
    frame = raw_frame[['spec', 'time', 'cache_reuse']].copy()
    frame.rename(columns={'time': 'Time', 'spec': 'Spec',
                         'cache_reuse': "Cache provided"}, inplace=True)
    frame['Caching'] = test
    frames.append(frame)
# More sensible order will be applied later
df_all = pd.concat(frames, axis=0).set_index(['Spec', 'Caching']).sort_index()

# %%
baselines = df_all[df_all['Cache provided'] == False]['Time'].unstack()

# %%
baselines_centered = (baselines.T - baselines.T.mean()).T
baselines_centered
# Out:
# Caching                 All  Falsely viable  Nonviable  Truly viable    Viable
# Spec
# l1/1d-conv         0.001595   -5.920480e-05   0.001004     -0.000130 -0.002409
# l1/1d-stencil      0.001241   -3.361912e-04   0.000929     -0.000435 -0.001399
# l1/2d-stencil-3   -0.000283    3.482886e-04  -0.000333      0.000479 -0.000211
# l1/2d-stencil-5   -0.003335    3.828324e-03  -0.005357      0.007775 -0.002912
# l1/2d-stencil-7    0.000187   -1.878894e-04   0.000278     -0.000080 -0.000197
# l1/mult-32-with-4 -0.001304   -1.358929e-03   0.002841      0.000956 -0.001134
# l1/trove-cr_sum-1 -0.000032    1.884000e-07   0.000031      0.000010 -0.000009
# l1/trove-cr_sum-2  0.003248   -1.047502e-03   0.002645     -0.001438 -0.003409
# l1/trove-cr_sum-3  0.003334   -1.300992e-03   0.003029     -0.001453 -0.003610
# l1/trove-cr_sum-4  0.048966   -1.942727e-02   0.049000     -0.021213 -0.057326
# l1/trove-cr_sum-5  0.005584   -2.490821e-03   0.004993     -0.001546 -0.006540
# l1/trove-cr_sum-7  0.004978   -2.291062e-03   0.007521     -0.003507 -0.006701
# l1/trove-crc-1     0.000020   -7.256200e-06   0.000012      0.000010 -0.000035
# l1/trove-crc-2     0.002660   -1.655072e-03   0.001855     -0.000502 -0.002358
# l1/trove-crc-3     0.002529   -2.416882e-04   0.003198     -0.002015 -0.003470
# l1/trove-crc-4     0.016810   -7.443027e-03   0.019051     -0.010264 -0.018154
# l1/trove-crc-5     0.008607   -6.580993e-03   0.009035     -0.006398 -0.004663
# l1/trove-crc-7     0.013226   -7.718857e-03   0.013403     -0.014785 -0.004125
# l1/trove-rcr-1    -0.000369    1.095852e-03  -0.000759      0.000503 -0.000470
# l1/trove-rcr-2     0.045874   -1.835715e-02   0.043051     -0.022117 -0.048451
# l1/trove-rcr-3     0.006074   -2.276037e-03   0.009501     -0.003091 -0.010208
# l1/trove-rcr-4     0.084015   -4.476299e-02   0.095232     -0.050106 -0.084379
# l1/trove-rcr-5     0.028483   -1.696281e-02   0.022406     -0.019797 -0.014129
# l1/trove-rcr-7     0.057544   -5.208337e-02   0.074379     -0.052195 -0.027644
# l2/1d-conv         0.003226   -1.446449e-03   0.002882     -0.000987 -0.003674
# l2/1d-stencil      0.002371   -1.478051e-03   0.002413     -0.001742 -0.001563
# l2/2d-stencil-3   -0.001064   -1.109420e-04   0.000089      0.001766 -0.000680
# l2/2d-stencil-5   -0.002057    2.717377e-03  -0.007271      0.011117 -0.004507
# l2/2d-stencil-7    0.043921   -1.081180e-01  -0.012681      0.064978  0.011900
# l2/mult-32-with-4 -0.000779   -1.090122e-03   0.001515      0.001579 -0.001225
# l3/1d-conv         0.004394   -1.040662e-04   0.002948     -0.001626 -0.005611
# l3/1d-stencil      0.002710   -8.342878e-04   0.002605     -0.001106 -0.003375
# l3/2d-stencil-3   -0.001033    7.675720e-04   0.000046      0.002525 -0.002306
# l3/2d-stencil-5   -0.006326    7.958208e-03  -0.006805      0.010737 -0.005564
# l3/2d-stencil-7    0.037987   -7.726705e-02  -0.008544      0.009881  0.037943
# l3/mult-32-with-4 -0.001057   -8.728574e-04   0.001750      0.001510 -0.001330
# l3/trove-cr_sum-1 -0.000029    5.836100e-05  -0.000001      0.000029 -0.000057
# l3/trove-cr_sum-2  0.011101   -3.204534e-03   0.001960     -0.004007 -0.005849
# l3/trove-cr_sum-3  0.004337   -1.418726e-03   0.005388     -0.002151 -0.006154
# l3/trove-cr_sum-4  0.058672   -5.348195e-02   0.122604     -0.020325 -0.107469
# l3/trove-cr_sum-5  0.006414   -2.733437e-03   0.006843     -0.002432 -0.008092
# l3/trove-crc-1     0.000054   -3.240480e-05   0.000052     -0.000026 -0.000049
# l3/trove-crc-2     0.003139   -1.726525e-03   0.003270     -0.001544 -0.003138
# l3/trove-crc-3     0.004173   -1.446818e-03   0.005159     -0.002932 -0.004953
# l3/trove-crc-4     0.013397   -1.866985e-02   0.042898     -0.004846 -0.032779
# l3/trove-crc-5     0.010853   -6.685796e-03   0.010418     -0.007623 -0.006962
# l3/trove-crc-7     0.015549   -1.221624e-02   0.017416     -0.013415 -0.007334
# l3/trove-rcr-1    -0.001339    2.166845e-03  -0.000747      0.001118 -0.001199
# l3/trove-rcr-2     0.590036   -2.509058e-01   0.587102     -0.311969 -0.614263
# l3/trove-rcr-3     0.006121   -1.096450e-02   0.032258      0.000162 -0.027576
# l3/trove-rcr-4     1.131871   -7.152313e-01   1.545462     -0.682696 -1.279406
# l3/trove-rcr-5     0.024640   -3.562626e-02   0.065589     -0.027228 -0.027375
# l3/trove-rcr-7     0.079612   -5.784343e-02   0.090072     -0.052362 -0.059478

# %%
baselines_centered.sum()
# Out:
# Caching
# All               2.370547
# Falsely viable   -1.531158
# Nonviable         2.871635
# Truly viable     -1.234956
# Viable           -2.476068
# dtype: float64

# %%
new_baselines_raw = fetch("2020-06-31-baseline-timings-for-cache-experiments")
new_baselines_df = pull_spec_in(select_categories(new_baselines_raw, ["search"]))
new_baselines = new_baselines_df.set_index('spec')['time']
new_baselines.index.name = 'Spec'

# %%
(baselines.T - new_baselines).T.mean(axis=1)
# Out:
# Spec
# l1/1d-conv           0.002704
# l1/1d-stencil        0.001588
# l1/2d-stencil-3      0.000663
# l1/2d-stencil-5      0.004895
# l1/2d-stencil-7      0.000302
# l1/mult-32-with-4   -0.000730
# l1/trove-cr_sum-1   -0.000014
# l1/trove-cr_sum-2    0.003550
# l1/trove-cr_sum-3    0.005207
# l1/trove-cr_sum-4    0.065546
# l1/trove-cr_sum-5    0.007651
# l1/trove-cr_sum-7    0.010434
# l1/trove-crc-1       0.000033
# l1/trove-crc-2       0.003380
# l1/trove-crc-3       0.005218
# l1/trove-crc-4       0.018765
# l1/trove-crc-5       0.007439
# l1/trove-crc-7       0.014654
# l1/trove-rcr-1       0.000510
# l1/trove-rcr-2       0.051204
# l1/trove-rcr-3       0.013289
# l1/trove-rcr-4       0.094755
# l1/trove-rcr-5       0.021660
# l1/trove-rcr-7       0.057810
# l2/1d-conv           0.004065
# l2/1d-stencil        0.002034
# l2/2d-stencil-3      0.001770
# l2/2d-stencil-5      0.011065
# l2/2d-stencil-7      0.129146
# l2/mult-32-with-4   -0.000636
# l3/1d-conv           0.006640
# l3/1d-stencil        0.002965
# l3/2d-stencil-3      0.002933
# l3/2d-stencil-5      0.011726
# l3/2d-stencil-7      0.113619
# l3/mult-32-with-4   -0.000762
# l3/trove-cr_sum-1    0.000039
# l3/trove-cr_sum-2    0.006164
# l3/trove-cr_sum-3    0.006650
# l3/trove-cr_sum-4    0.088253
# l3/trove-cr_sum-5    0.010398
# l3/trove-crc-1       0.000078
# l3/trove-crc-2       0.004018
# l3/trove-crc-3       0.006373
# l3/trove-crc-4       0.023539
# l3/trove-crc-5       0.009582
# l3/trove-crc-7       0.016010
# l3/trove-rcr-1      -0.001668
# l3/trove-rcr-2       0.669407
# l3/trove-rcr-3       0.015215
# l3/trove-rcr-4       1.307108
# l3/trove-rcr-5       0.031522
# l3/trove-rcr-7       0.048556
# dtype: float64

# %% [markdown]
# We can real quick conclude that there was overhead in creating the caches we need to account for

# %%
cache_states = df_all[df_all['Cache provided']]['Time'].unstack()
cache_states.insert(0, "Baseline", new_baselines.sort_index())

# %%
df = cache_states.sort_values(by="Baseline", ascending=False)
df.head()
# Out:
# Caching          Baseline       All  Falsely viable  Nonviable  Truly viable  \
# Spec
# l3/trove-rcr-4   2.555434  3.771795        2.540714   5.135037      2.938958
# l3/2d-stencil-7  2.413099  0.067489        0.989484   2.334861      1.710015
# l2/2d-stencil-7  2.397980  0.066822        0.990923   2.336182      1.689201
# l3/trove-rcr-2   1.111086  2.087196        1.398469   2.429911      1.377603
# l3/trove-rcr-7   0.299529  0.122987        0.101266   0.418696      0.269802
#
# Caching            Viable
# Spec
# l3/trove-rcr-4   1.865731
# l3/2d-stencil-7  0.186668
# l2/2d-stencil-7  0.187467
# l3/trove-rcr-2   1.001386
# l3/trove-rcr-7   0.066527

# %%
speedups = 1.0 / (df.div(df['Baseline'], axis=0))

# %%
speedups.head()
# Out:
# Caching          Baseline        All  Falsely viable  Nonviable  Truly viable  \
# Spec
# l3/trove-rcr-4        1.0   0.677511        1.005793   0.497647      0.869503
# l3/2d-stencil-7       1.0  35.755353        2.438745   1.033509      1.411157
# l2/2d-stencil-7       1.0  35.886271        2.419945   1.026452      1.419594
# l3/trove-rcr-2        1.0   0.532334        0.794502   0.457254      0.806536
# l3/trove-rcr-7        1.0   2.435445        2.957827   0.715385      1.110181
#
# Caching             Viable
# Spec
# l3/trove-rcr-4    1.369669
# l3/2d-stencil-7  12.927239
# l2/2d-stencil-7  12.791502
# l3/trove-rcr-2    1.109548
# l3/trove-rcr-7    4.502393

# %%
df.to_csv('../results/2020-06-31-effects-of-caching-on-search-time.csv')
speedups.to_csv('../results/2020-06-31-effects-of-caching-on-search-time-speedups.csv')
