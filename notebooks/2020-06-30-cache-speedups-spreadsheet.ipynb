# %%
import sys
sys.path.append("../analysis")

# %%
import parsing
import extraction
import utils

# %%
from extraction import pull_spec_in, select_categories
from utils import fetch, split_spec_pretty

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
STATE_CACHE_FILES = {
    "Viable (ideal results)": '2020-06-29-cache-all-viable-with-ultimate-result',
    "Viable (actual results)": '2020-06-31-cache-continuing-on-viable',
    "Falsely viable (ideal results)": '2020-06-29-cache-false-on-viable-but-mistaken',
    "Falsely viable (actual results)": '2020-06-31-cache-continuing-with-false-pasitives',
    "Truly viable": '2020-06-29-cache-on-viable-and-in-solution',
    "Nonviable": '2020-06-29-cache-only-when-nonviable',
    "All (ideal results)": '2020-06-29-cache-all-pruning-results'
}

# %%
data = {t: pull_spec_in(select_categories(fetch(f), ["search"]))
       for t, f in STATE_CACHE_FILES.items()}

# %%
data['Viable (ideal results)'].columns
# Out:
# Index(['category', 'key', 'success', 'mode', 'cache_reuse', 'prune_fuel',
#        'time', 'spec'],
#       dtype='object')

# %%
frames = []
for test, raw_frame in data.items():
    frame = raw_frame[['spec', 'time', 'cache_reuse']].copy()
    frame.rename(columns={'time': 'Time', 'spec': 'Spec',
                         'cache_reuse': "Cache provided"}, inplace=True)
    frame['Caching'] = test
    frames.append(frame)
# More sensible order will be applied later
df_all = pd.concat(frames, axis=0).set_index(['Spec', 'Caching']).sort_index()

# %%
baselines = df_all[df_all['Cache provided'] == False]['Time'].unstack()

# %%
baselines_centered = (baselines.T - baselines.T.mean()).T
baselines_centered
# Out:
# Caching            All (ideal results)  Falsely viable (actual results)  \
# Spec
# l1/1d-conv                    0.001968                     1.279757e-05
# l1/1d-stencil                 0.001473                    -5.647329e-05
# l1/2d-stencil-3              -0.000276                     2.536891e-04
# l1/2d-stencil-5              -0.006853                     2.551430e-02
# l1/2d-stencil-7               0.000255                    -1.804221e-04
# l1/mult-32-with-4            -0.001348                    -6.331471e-05
# l1/trove-cr_sum-1            -0.000032                    -4.528571e-08
# l1/trove-cr_sum-2             0.003861                    -7.648513e-04
# l1/trove-cr_sum-3             0.004204                    -9.520413e-04
# l1/trove-cr_sum-4             0.057900                    -1.695550e-02
# l1/trove-cr_sum-5             0.006815                    -1.398620e-03
# l1/trove-cr_sum-7             0.006446                    -2.426808e-03
# l1/trove-crc-1                0.000023                    -7.482857e-07
# l1/trove-crc-2                0.003212                    -2.123671e-04
# l1/trove-crc-3                0.002902                     4.982580e-04
# l1/trove-crc-4                0.020656                    -4.750558e-03
# l1/trove-crc-5                0.010012                    -3.570514e-03
# l1/trove-crc-7                0.016702                    -8.509829e-03
# l1/trove-rcr-1               -0.000412                     1.201149e-04
# l1/trove-rcr-2                0.055547                    -1.064874e-02
# l1/trove-rcr-3                0.007844                    -1.060245e-03
# l1/trove-rcr-4                0.104612                    -3.243528e-02
# l1/trove-rcr-5                0.032772                    -9.318774e-03
# l1/trove-rcr-7                0.072123                    -2.742030e-02
# l2/1d-conv                    0.004012                    -3.708717e-04
# l2/1d-stencil                 0.002906                    -1.696474e-03
# l2/2d-stencil-3              -0.001007                     1.240657e-03
# l2/2d-stencil-5              -0.001575                     3.474696e-03
# l2/2d-stencil-7               0.065840                    -1.023482e-01
# l2/mult-32-with-4            -0.000986                     6.360859e-04
# l3/1d-conv                    0.005202                     3.053264e-04
# l3/1d-stencil                 0.003260                     1.946100e-05
# l3/2d-stencil-3              -0.000982                     1.031375e-03
# l3/2d-stencil-5              -0.005893                     4.065259e-03
# l3/2d-stencil-7               0.055151                    -9.631261e-02
# l3/mult-32-with-4            -0.001269                     4.394104e-04
# l3/trove-cr_sum-1            -0.000041                    -2.496571e-06
# l3/trove-cr_sum-2             0.012585                    -2.708839e-03
# l3/trove-cr_sum-3             0.005364                    -5.619061e-04
# l3/trove-cr_sum-4             0.069511                     1.350515e-03
# l3/trove-cr_sum-5             0.008002                    -1.208029e-03
# l3/trove-crc-1                0.000065                    -2.257843e-05
# l3/trove-crc-2                0.003837                    -9.501807e-04
# l3/trove-crc-3                0.005157                    -8.945971e-04
# l3/trove-crc-4                0.015528                     7.602693e-03
# l3/trove-crc-5                0.012500                    -4.180324e-03
# l3/trove-crc-7                0.019693                    -9.702506e-03
# l3/trove-rcr-1               -0.001454                     1.390677e-03
# l3/trove-rcr-2                0.710780                    -1.589728e-01
# l3/trove-rcr-3                0.008387                     3.803090e-03
# l3/trove-rcr-4                1.389136                    -4.083406e-01
# l3/trove-rcr-5                0.032647                    -2.258706e-02
# l3/trove-rcr-7                0.092602                    -2.885154e-02
#
# Caching            Falsely viable (ideal results)  Nonviable  Truly viable  \
# Spec
# l1/1d-conv                           3.140106e-04   0.001377      0.000243
# l1/1d-stencil                       -1.047823e-04   0.001161     -0.000204
# l1/2d-stencil-3                      3.549531e-04  -0.000326      0.000485
# l1/2d-stencil-5                      3.098156e-04  -0.008876      0.004257
# l1/2d-stencil-7                     -1.200011e-04   0.000346     -0.000012
# l1/mult-32-with-4                   -1.402347e-03   0.002798      0.000913
# l1/trove-cr_sum-1                   -1.652857e-07   0.000030      0.000009
# l1/trove-cr_sum-2                   -4.347993e-04   0.003258     -0.000825
# l1/trove-cr_sum-3                   -4.309043e-04   0.003899     -0.000583
# l1/trove-cr_sum-4                   -1.049274e-02   0.057935     -0.012278
# l1/trove-cr_sum-5                   -1.260043e-03   0.006224     -0.000315
# l1/trove-cr_sum-7                   -8.230844e-04   0.008989     -0.002039
# l1/trove-crc-1                      -4.251286e-06   0.000015      0.000013
# l1/trove-crc-2                      -1.103634e-03   0.002407      0.000049
# l1/trove-crc-3                       1.312650e-04   0.003570     -0.001642
# l1/trove-crc-4                      -3.597636e-03   0.022896     -0.006419
# l1/trove-crc-5                      -5.176434e-03   0.010440     -0.004994
# l1/trove-crc-7                      -4.241954e-03   0.016880     -0.011308
# l1/trove-rcr-1                       1.053299e-03  -0.000801      0.000460
# l1/trove-rcr-2                      -8.684267e-03   0.052724     -0.012445
# l1/trove-rcr-3                      -5.066660e-04   0.011270     -0.001322
# l1/trove-rcr-4                      -2.416591e-02   0.115829     -0.029509
# l1/trove-rcr-5                      -1.267390e-02   0.026695     -0.015509
# l1/trove-rcr-7                      -3.750468e-02   0.088958     -0.037617
# l2/1d-conv                          -6.598637e-04   0.003669     -0.000201
# l2/1d-stencil                       -9.427654e-04   0.002948     -0.001207
# l2/2d-stencil-3                     -5.453886e-05   0.000145      0.001822
# l2/2d-stencil-5                      3.199301e-03  -0.006789      0.011599
# l2/2d-stencil-7                     -8.619919e-02   0.009238      0.086897
# l2/mult-32-with-4                   -1.297472e-03   0.001307      0.001372
# l3/1d-conv                           7.042424e-04   0.003756     -0.000818
# l3/1d-stencil                       -2.845080e-04   0.003154     -0.000556
# l3/2d-stencil-3                      8.186004e-04   0.000097      0.002576
# l3/2d-stencil-5                      8.391320e-03  -0.006372      0.011170
# l3/2d-stencil-7                     -6.010362e-02   0.008619      0.027045
# l3/mult-32-with-4                   -1.085220e-03   0.001537      0.001297
# l3/trove-cr_sum-1                    4.700643e-05  -0.000012      0.000018
# l3/trove-cr_sum-2                   -1.720090e-03   0.003444     -0.002523
# l3/trove-cr_sum-3                   -3.918631e-04   0.006415     -0.001124
# l3/trove-cr_sum-4                   -4.264271e-02   0.133444     -0.009486
# l3/trove-cr_sum-5                   -1.145648e-03   0.008431     -0.000844
# l3/trove-crc-1                      -2.218143e-05   0.000062     -0.000015
# l3/trove-crc-2                      -1.028416e-03   0.003968     -0.000846
# l3/trove-crc-3                      -4.621511e-04   0.006144     -0.001947
# l3/trove-crc-4                      -1.653883e-02   0.045029     -0.002715
# l3/trove-crc-5                      -5.038337e-03   0.012065     -0.005976
# l3/trove-crc-7                      -8.072413e-03   0.021560     -0.009271
# l3/trove-rcr-1                       2.051896e-03  -0.000862      0.001003
# l3/trove-rcr-2                      -1.301615e-01   0.707846     -0.191224
# l3/trove-rcr-3                      -8.697791e-03   0.034525      0.002429
# l3/trove-rcr-4                      -4.579662e-01   1.802728     -0.425431
# l3/trove-rcr-5                      -2.761922e-02   0.073596     -0.019221
# l3/trove-rcr-7                      -4.485343e-02   0.103062     -0.039372
#
# Caching            Viable (actual results)  Viable (ideal results)
# Spec
# l1/1d-conv                       -0.001879               -0.002036
# l1/1d-stencil                    -0.001101               -0.001168
# l1/2d-stencil-3                  -0.000287               -0.000204
# l1/2d-stencil-5                  -0.007922               -0.006431
# l1/2d-stencil-7                  -0.000159               -0.000129
# l1/mult-32-with-4                 0.000280               -0.001178
# l1/trove-cr_sum-1                 0.000002               -0.000009
# l1/trove-cr_sum-2                -0.002299               -0.002796
# l1/trove-cr_sum-3                -0.003398               -0.002739
# l1/trove-cr_sum-4                -0.027717               -0.048391
# l1/trove-cr_sum-5                -0.004755               -0.005309
# l1/trove-cr_sum-7                -0.004913               -0.005233
# l1/trove-crc-1                   -0.000014               -0.000032
# l1/trove-crc-2                   -0.002545               -0.001807
# l1/trove-crc-3                   -0.002363               -0.003097
# l1/trove-crc-4                   -0.014476               -0.014309
# l1/trove-crc-5                   -0.003452               -0.003259
# l1/trove-crc-7                   -0.008875               -0.000648
# l1/trove-rcr-1                    0.000093               -0.000513
# l1/trove-rcr-2                   -0.037716               -0.038778
# l1/trove-rcr-3                   -0.007787               -0.008438
# l1/trove-rcr-4                   -0.070550               -0.063781
# l1/trove-rcr-5                   -0.012126               -0.009840
# l1/trove-rcr-7                   -0.045473               -0.013065
# l2/1d-conv                       -0.003562               -0.002888
# l2/1d-stencil                    -0.000980               -0.001028
# l2/2d-stencil-3                  -0.001523               -0.000623
# l2/2d-stencil-5                  -0.005884               -0.004025
# l2/2d-stencil-7                  -0.007246                0.033818
# l2/mult-32-with-4                 0.000401               -0.001432
# l3/1d-conv                       -0.004347               -0.004803
# l3/1d-stencil                    -0.002768               -0.002825
# l3/2d-stencil-3                  -0.001287               -0.002255
# l3/2d-stencil-5                  -0.006231               -0.005131
# l3/2d-stencil-7                   0.010495                0.055106
# l3/mult-32-with-4                 0.000622               -0.001542
# l3/trove-cr_sum-1                 0.000059               -0.000068
# l3/trove-cr_sum-2                -0.004713               -0.004364
# l3/trove-cr_sum-3                -0.004572               -0.005127
# l3/trove-cr_sum-4                -0.055547               -0.096630
# l3/trove-cr_sum-5                -0.006731               -0.006504
# l3/trove-crc-1                   -0.000029               -0.000038
# l3/trove-crc-2                   -0.002540               -0.002440
# l3/trove-crc-3                   -0.004029               -0.003969
# l3/trove-crc-4                   -0.018258               -0.030648
# l3/trove-crc-5                   -0.004057               -0.005314
# l3/trove-crc-7                   -0.011017               -0.003190
# l3/trove-rcr-1                   -0.000816               -0.001314
# l3/trove-rcr-2                   -0.444749               -0.493519
# l3/trove-rcr-3                   -0.015137               -0.025310
# l3/trove-rcr-4                   -0.877985               -1.022141
# l3/trove-rcr-5                   -0.017448               -0.019368
# l3/trove-rcr-7                   -0.036098               -0.046488

# %%
baselines_centered.sum()
# Out:
# Caching
# All (ideal results)                2.909365
# Falsely viable (actual results)   -0.908679
# Falsely viable (ideal results)    -0.992340
# Nonviable                          3.410452
# Truly viable                      -0.696139
# Viable (actual results)           -1.785407
# Viable (ideal results)            -1.937251
# dtype: float64

# %%
new_baselines_raw = fetch("2020-06-31-baseline-timings-for-cache-experiments")
new_baselines_df = pull_spec_in(select_categories(new_baselines_raw, ["search"]))
new_baselines = new_baselines_df.set_index('spec')['time']
new_baselines.index.name = 'Spec'

# %%
(baselines.T - new_baselines).T.mean(axis=1)
# Out:
# Spec
# l1/1d-conv           0.002331
# l1/1d-stencil        0.001356
# l1/2d-stencil-3      0.000656
# l1/2d-stencil-5      0.008414
# l1/2d-stencil-7      0.000234
# l1/mult-32-with-4   -0.000686
# l1/trove-cr_sum-1   -0.000013
# l1/trove-cr_sum-2    0.002937
# l1/trove-cr_sum-3    0.004337
# l1/trove-cr_sum-4    0.056611
# l1/trove-cr_sum-5    0.006420
# l1/trove-cr_sum-7    0.008966
# l1/trove-crc-1       0.000030
# l1/trove-crc-2       0.002828
# l1/trove-crc-3       0.004845
# l1/trove-crc-4       0.014920
# l1/trove-crc-5       0.006034
# l1/trove-crc-7       0.011177
# l1/trove-rcr-1       0.000553
# l1/trove-rcr-2       0.041531
# l1/trove-rcr-3       0.011519
# l1/trove-rcr-4       0.074158
# l1/trove-rcr-5       0.017371
# l1/trove-rcr-7       0.043231
# l2/1d-conv           0.003279
# l2/1d-stencil        0.001498
# l2/2d-stencil-3      0.001713
# l2/2d-stencil-5      0.010583
# l2/2d-stencil-7      0.107227
# l2/mult-32-with-4   -0.000429
# l3/1d-conv           0.005831
# l3/1d-stencil        0.002415
# l3/2d-stencil-3      0.002882
# l3/2d-stencil-5      0.011293
# l3/2d-stencil-7      0.096456
# l3/mult-32-with-4   -0.000549
# l3/trove-cr_sum-1    0.000051
# l3/trove-cr_sum-2    0.004680
# l3/trove-cr_sum-3    0.005623
# l3/trove-cr_sum-4    0.077414
# l3/trove-cr_sum-5    0.008810
# l3/trove-crc-1       0.000067
# l3/trove-crc-2       0.003320
# l3/trove-crc-3       0.005388
# l3/trove-crc-4       0.021408
# l3/trove-crc-5       0.007935
# l3/trove-crc-7       0.011867
# l3/trove-rcr-1      -0.001553
# l3/trove-rcr-2       0.548663
# l3/trove-rcr-3       0.012948
# l3/trove-rcr-4       1.049843
# l3/trove-rcr-5       0.023515
# l3/trove-rcr-7       0.035566
# dtype: float64

# %% [markdown]
# We can real quick conclude that there was overhead in creating the caches we need to account for

# %%
cache_states = df_all[df_all['Cache provided']]['Time'].unstack()
cache_states.insert(0, "Baseline", new_baselines.sort_index())

# %%
df = cache_states.sort_values(by="Baseline", ascending=False)
df.head()
# Out:
# Caching          Baseline  All (ideal results)  \
# Spec
# l3/trove-rcr-4   2.555434             3.771795
# l3/2d-stencil-7  2.413099             0.067489
# l2/2d-stencil-7  2.397980             0.066822
# l3/trove-rcr-2   1.111086             2.087196
# l3/trove-rcr-7   0.299529             0.122987
#
# Caching          Falsely viable (actual results)  \
# Spec
# l3/trove-rcr-4                          3.146353
# l3/2d-stencil-7                         1.007857
# l2/2d-stencil-7                         1.022351
# l3/trove-rcr-2                          1.494358
# l3/trove-rcr-7                          0.166214
#
# Caching          Falsely viable (ideal results)  Nonviable  Truly viable  \
# Spec
# l3/trove-rcr-4                         2.540714   5.135037      2.938958
# l3/2d-stencil-7                        0.989484   2.334861      1.710015
# l2/2d-stencil-7                        0.990923   2.336182      1.689201
# l3/trove-rcr-2                         1.398469   2.429911      1.377603
# l3/trove-rcr-7                         0.101266   0.418696      0.269802
#
# Caching          Viable (actual results)  Viable (ideal results)
# Spec
# l3/trove-rcr-4                  2.335259                1.865731
# l3/2d-stencil-7                 0.224646                0.186668
# l2/2d-stencil-7                 0.216408                0.187467
# l3/trove-rcr-2                  1.105856                1.001386
# l3/trove-rcr-7                  0.138052                0.066527

# %%
speedups = 1.0 / (df.div(df['Baseline'], axis=0))

# %%
speedups.head()
# Out:
# Caching          Baseline  All (ideal results)  \
# Spec
# l3/trove-rcr-4        1.0             0.677511
# l3/2d-stencil-7       1.0            35.755353
# l2/2d-stencil-7       1.0            35.886271
# l3/trove-rcr-2        1.0             0.532334
# l3/trove-rcr-7        1.0             2.435445
#
# Caching          Falsely viable (actual results)  \
# Spec
# l3/trove-rcr-4                          0.812189
# l3/2d-stencil-7                         2.394286
# l2/2d-stencil-7                         2.345555
# l3/trove-rcr-2                          0.743521
# l3/trove-rcr-7                          1.802062
#
# Caching          Falsely viable (ideal results)  Nonviable  Truly viable  \
# Spec
# l3/trove-rcr-4                         1.005793   0.497647      0.869503
# l3/2d-stencil-7                        2.438745   1.033509      1.411157
# l2/2d-stencil-7                        2.419945   1.026452      1.419594
# l3/trove-rcr-2                         0.794502   0.457254      0.806536
# l3/trove-rcr-7                         2.957827   0.715385      1.110181
#
# Caching          Viable (actual results)  Viable (ideal results)
# Spec
# l3/trove-rcr-4                  1.094283                1.369669
# l3/2d-stencil-7                10.741767               12.927239
# l2/2d-stencil-7                11.080831               12.791502
# l3/trove-rcr-2                  1.004730                1.109548
# l3/trove-rcr-7                  2.169683                4.502393

# %%
df.to_csv('../results/2020-06-31-effects-of-caching-on-search-time.csv')
speedups.to_csv('../results/2020-06-31-effects-of-caching-on-search-time-speedups.csv')
